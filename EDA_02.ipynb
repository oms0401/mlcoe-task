# %% [markdown]
# <a href="https://colab.research.google.com/github/oms0401/mlcoe-task/blob/main/EDA_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MLCOE TASK -2 EDA ON DATASET

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/MLCOE Task 1 - second_draft.csv')

# %% [markdown]
# **Knowing our data**

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.sample(10)
# Out:
#       Customer ID   Age  Gender Item Purchased     Category  \
# 2133         2134  21.0    Male            Hat  Accessories
# 3100         3101  50.0  Female            Hat  Accessories
# 2572         2573  54.0    Male         Blouse     Clothing
# 3624         3625  22.0  Female            Hat  Accessories
# 2631         2632  53.0    Male          Skirt     Clothing
# 1876         1877  54.0    Male          Skirt     Clothing
# 113           114  44.0    Male            Hat  Accessories
# 3704         3705  68.0  Female     Sunglasses  Accessories
# 3225         3226  53.0  Female         Blouse     Clothing
# 842           843  59.0    Male          Shirt     Clothing
#
#       Purchase Amount (USD)       Location Size   Color  Season  \
# 2133                   34.0          Maine    M   Olive  Summer
# 3100                   85.0        Vermont    L  Purple  Winter
# 2572                   42.0     Washington    M  Silver    Fall
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3269 non-null   float64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3285 non-null   float64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3246 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df.shape
# Out:
# (3900, 19)

# %%
df.isnull()
# Out:
#       Customer ID    Age  Gender  Item Purchased  Category  \
# 0           False   True   False           False     False
# 1           False   True   False           False     False
# 2           False   True   False           False     False
# 3           False   True   False           False     False
# 4           False   True   False           False     False
# ...           ...    ...     ...             ...       ...
# 3895        False  False   False           False     False
# 3896        False  False   False           False     False
# 3897        False  False   False           False     False
# 3898        False  False   False           False     False
# 3899        False  False   False           False     False
#
#       Purchase Amount (USD)  Location   Size  Color  Season  Review Rating  \
# 0                      True     False  False  False   False           True
# 1                      True     False  False  False   False           True
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3269.000000            3285.000000    3246.000000
# mean   1950.500000    43.973998              59.863014       3.744239
# std    1125.977353    15.216359              23.673623       0.719448
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.750000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
'''
checking the missing values
'''
# Out:
# '\nchecking the missing values\n'

# %%
df.isnull().sum()
# Out:
# Customer ID                   0
# Age                         631
# Gender                        0
# Item Purchased                0
# Category                      0
# Purchase Amount (USD)       615
# Location                      0
# Size                          0
# Color                         0
# Season                        0
# Review Rating               654
# Subscription Status           0
# Payment Method                0
# Shipping Type                 0
# Discount Applied              0
# Promo Code Used               0
# Previous Purchases            0
# Preferred Payment Method      0
# Frequency of Purchases        0
# dtype: int64

# %%
df.shape
# Out:
# (3900, 19)

# %% [markdown]
# handling the missing value of age

# %%
df['Age'].fillna('43')
# Out:
# 0         43
# 1         43
# 2         43
# 3         43
# 4         43
#         ...
# 3895    40.0
# 3896    52.0
# 3897    46.0
# 3898    44.0
# 3899    52.0
# Name: Age, Length: 3900, dtype: object

# %%
df['Purchase Amount (USD)'].mode()[0]
# Out:
# 25.0

# %% [markdown]
# handling the missing value of purchase amount

# %%
df['Purchase Amount (USD)'].fillna(25)
# Out:
# 0       25.0
# 1       25.0
# 2       25.0
# 3       90.0
# 4       25.0
#         ...
# 3895    28.0
# 3896    49.0
# 3897    33.0
# 3898    77.0
# 3899    25.0
# Name: Purchase Amount (USD), Length: 3900, dtype: float64

# %% [markdown]
# Handling the missing the value of review rating

# %%
df['Review Rating'].dropna()
# Out:
# 5       2.9
# 6       3.2
# 7       3.2
# 10      4.1
# 11      4.9
#        ...
# 3895    4.2
# 3896    4.5
# 3897    2.9
# 3898    3.8
# 3899    3.1
# Name: Review Rating, Length: 3246, dtype: float64

# %%
df.corr()
# Out:
# <ipython-input-52-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                        Customer ID       Age  Purchase Amount (USD)  \
# Customer ID               1.000000 -0.009066               0.013169
# Age                      -0.009066  1.000000              -0.010660
# Purchase Amount (USD)     0.013169 -0.010660               1.000000
# Review Rating            -0.002597 -0.023811               0.036734
# Previous Purchases       -0.039159  0.040187               0.009703
#
#                        Review Rating  Previous Purchases
# Customer ID                -0.002597           -0.039159
# Age                        -0.023811            0.040187
# Purchase Amount (USD)       0.036734            0.009703
# Review Rating               1.000000            0.006211
# ...

# %% [markdown]
# **UNIVARIATE ANALYSIS**

# %%
sns.distplot(df['Age'],hist=False)
# Out:
# <ipython-input-68-139237e0c63e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Purchase Amount (USD)'])
# Out:
# <Axes: >

# %%
sns.violinplot(df['Previous Purchases'])
# Out:
# <Axes: >

# %%
df['Item Purchased'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Item Purchased'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Item Purchased'>

# %%
df['Subscription Status'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
sns.countplot(x=df['Gender'],data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
color=df['Color'].value_counts().plot(kind='pie')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3269 non-null   float64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3285 non-null   float64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3246 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df['Size'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# **BIVARIATE and MULTI ANALYSIS**

# %%
sns.relplot(x='Previous Purchases',y='Purchase Amount (USD)',kind='scatter',hue='Gender',data=df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3269 non-null   float64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3285 non-null   float64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3246 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
sns.countplot(x=df['Category'],hue=df['Gender'],data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.pairplot(df)

# %%
corr=df.corr()
sns.clustermap(corr)
# Out:
# <ipython-input-70-d1c255eb2981>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()

# %%
sns.boxplot(x='Previous Purchases',y='Category',hue='Gender',data=df)
plt.show()
